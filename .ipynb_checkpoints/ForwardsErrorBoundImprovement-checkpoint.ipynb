# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# The goal of the notebook is to evaluate and characterize the following integral:

# %% [markdown]
# $$
# integral(j,radius) = \int_{\Gamma} \left(\frac{z}{w(t)}\right)^j \frac{dw}{w}
# $$

# %% [markdown]
# where our origin is centered $r$ away from $z$ on the interior $D_{-}$.
#
#
# For the specific case of the notebook we choose an a=3,b=2, ellipse,
# and our target is located at $(3,0)$

# %%
#Geometry Setup
def shape_ellipse(t,a=3,b=2):
    return np.array([a*np.cos(t),b*np.sin(t)])
def tangent_derivative(t,a=3,b=2):
    return np.linalg.norm(np.array([-a*np.sin(t),b*np.cos(t)]),axis=0)


#Define Qaudrature Points (Trapezoid)
N = 200000
#x = np.polynomial.legendre.leggauss(N)
points = np.array([2*np.pi*i/N for i in range(N)]) -  np.pi #x[0]
weights = np.array([2*np.pi/N for i in range(N)])#x[1]

# %%
#Check That Tangent Derivatives Give Arc-Length, Arc-Length Approx 15.87
np.sum(tangent_derivative(points)*weights)
# Out:
# 15.865439589290588

# %%
#Define Integrand
def f(t,j,radius=0.1):
    origin = np.array([3-radius, 0])
    return radius**j/np.linalg.norm(shape_ellipse(t) - origin[:,None],axis=0)**(j+1)

# %%
#Plot Integrand for a few orders:
plt.plot(points, f(points, 0, radius = 0.8), label='0')
plt.plot(points, f(points, 1, radius = 0.8), label='5')
plt.plot(points, f(points, 2, radius = 0.8), label='20')
plt.legend()
plt.show()

# %%
#Integrate integrand for N orders at a given radius
def integrate(N,radius,start=0):
    decay_behavior = []
    for i in range(start, start+N):
        integrand = f(points,i,radius) * tangent_derivative(points)
        integral = np.sum(integrand*weights) 
        decay_behavior.append(integral)
    return decay_behavior

# %%
#Plot Integral as Function of j, for radius = 0.1/0.001, 10 orders
N = 10
r1 = 0.1
r2 = 0.01
r3 = 0.005
factor =  np.log(1/r1)/np.log(1/r2)
print(factor)
plt.semilogy(np.array([i for i in range(N)]),np.array(integrate(N,r1,0)),label="radius = "+str(r1)) 
plt.semilogy(np.array([i for i in range(N)]),np.array(integrate(N,r2,0)),label="radius = "+str(r2)) 
plt.semilogy(np.array([i for i in range(N)]),np.array(integrate(N,r3,0)),label="radius = "+str(r3)) 
#plt.semilogy(np.array([i for i in range(N)]),np.array(integrate(N,0.1,100)),label="start=100,radius = 0.1")
#plt.semilogy(np.array([i for i in range(N)]),np.array(integrate(N,0.01,200)),label="start=100,radius = 0.01")
print("true factor", np.array(integrate(N,r1))[0]/np.array(integrate(N,r2))[0] )
plt.legend()
plt.xlabel("value of j")
plt.ylabel("integral(j, radius)")
plt.title("SemiLogY Plot")
plt.show()
# Out:
# 0.5
# true factor 0.7117842587042393

# %%
#Plot Integral as Function of j, for radius = 0.1/0.001, 10 orders
N = 10
r1 = 0.1
r2 = 0.01
r3 = 0.005
factor =  np.log(1/r1)/np.log(1/r2)
shift = 1
plt.semilogy(np.array([i+shift for i in range(N)]),np.array(integrate(N,r1,shift)),label="radius = "+str(r1)) 
plt.semilogy(np.array([i+shift for i in range(N)]),np.array(integrate(N,r2,shift)),label="radius = "+str(r2)) 
plt.semilogy(np.array([i+shift for i in range(N)]),np.array(integrate(N,r3,shift)),label="radius = "+str(r3)) 
#plt.semilogy(np.array([i for i in range(N)]),np.array(integrate(N,0.1,100)),label="start=100,radius = 0.1")
#plt.semilogy(np.array([i for i in range(N)]),np.array(integrate(N,0.01,200)),label="start=100,radius = 0.01")
#print("true factor", np.array(integrate(N,r1))[0]/np.array(integrate(N,r2))[0] )
plt.legend()
plt.xlabel("value of j")
plt.ylabel("integral(j, radius)")
plt.title("SemiLogY Plot")
plt.show()

# %%
"Final conclusion it seems that for a given order, each coefficient seems to decrease with a small enough r"
'This seems to go against Epsteins hunch of a log(1/r) bound. It seems he is correct for lower order terms'

'Ep ignores the contribution of the integrand for higher orders. I have cranked up the quadrature as high as pos.'
# Out:
# 'Ep ignores the contribution of the integrand for higher orders. I have cranked up the quadrature as high as pos.'

# %%
'I was wrong about the solid angle viewpoint. It does not work when taking norms. However it did open me up to'
'the idea that the integral doesnt diverge like log(1/r) which is what we see here for higher order terms'
# Out:
# 'the idea that the integral doesnt diverge like log(1/r) which is what we see here for higher order terms'

# %%
'Meaning that there is still hope for a refined forwards bound. I would leave things as is for the next month'
'and primarily focus on target-specific expansions before returning to this interesting data.'
# Out:
# 'and primarily focus on target-specific expansions before returning to this interesting data.'

# %%
"Note that a shift as much as 1 seems to lead to a decreasing coefficient at each order >=1"
# Out:
# 'Note that a shift as much as 1 seems to lead to a decreasing coefficient at each order >=1'

# %%
'Use self-analysis. Use hard data to convince yourself of what is worth pursuing rather than feelings.'
'3/13/2024 9:33PM'
# Out:
# '3/13/2024 9:33PM'
